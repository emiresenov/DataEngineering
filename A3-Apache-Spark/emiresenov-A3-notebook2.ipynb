# %% [markdown]
# ## Application settings

# %%
from pyspark.sql import SparkSession


spark_session = SparkSession.builder\
    .master("spark://192.168.2.70:7077") \
    .appName("emiresenov")\
    .config("spark.dynamicAllocation.enabled", True)\
    .config("spark.dynamicAllocation.shuffleTracking.enabled",True)\
    .config("spark.shuffle.service.enabled", True)\
    .config("spark.dynamicAllocation.executorIdleTimeout","30s")\
    .config("spark.cores.max", 4)\
    .getOrCreate()
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/home/ubuntu/.local/lib/python3.10/site-packages/pyspark/jars/spark-unsafe_2.12-3.2.3.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/02/17 12:26:37 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## Section B

# %%
# B.1 - Load the CSV file and call show()
df = spark_session.read.option("header",True).csv('hdfs://192.168.2.70:9000/parking-citations.csv')

df.show(truncate=False, vertical=True) # Display as vertical for nicer formatting
# Out:
# -RECORD 0-----------------------------------------
#  Ticket number          | 1103341116
#  Issue Date             | 2015-12-21T00:00:00.000
#  Issue time             | 1251
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 200304
#  VIN                    | null
#  Make                   | HOND
#  Body Style             | PA
#  Color                  | GY
#  Location               | 13147 WELBY WAY
#  Route                  | 01521
#  Agency                 | 1
#  Violation code         | 4000A1
#  Violation Description  | NO EVIDENCE OF REG
#  Fine amount            | 50
#  Latitude               | 99999
#  Longitude              | 99999
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 1-----------------------------------------
#  Ticket number          | 1103700150
#  Issue Date             | 2015-12-21T00:00:00.000
#  Issue time             | 1435
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201512
#  VIN                    | null
#  Make                   | GMC
#  Body Style             | VN
#  Color                  | WH
#  Location               | 525 S MAIN ST
#  Route                  | 1C51
#  Agency                 | 1
#  Violation code         | 4000A1
#  Violation Description  | NO EVIDENCE OF REG
#  Fine amount            | 50
#  Latitude               | 99999
#  Longitude              | 99999
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 2-----------------------------------------
#  Ticket number          | 1104803000
#  Issue Date             | 2015-12-21T00:00:00.000
#  Issue time             | 2055
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201503
#  VIN                    | null
#  Make                   | NISS
#  Body Style             | PA
#  Color                  | BK
#  Location               | 200 WORLD WAY
#  Route                  | 2R2
#  Agency                 | 2
#  Violation code         | 8939
#  Violation Description  | WHITE CURB
#  Fine amount            | 58
#  Latitude               | 6439997.9
#  Longitude              | 1802686.4
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 3-----------------------------------------
#  Ticket number          | 1104820732
#  Issue Date             | 2015-12-26T00:00:00.000
#  Issue time             | 1515
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | null
#  VIN                    | null
#  Make                   | ACUR
#  Body Style             | PA
#  Color                  | WH
#  Location               | 100 WORLD WAY
#  Route                  | 2F11
#  Agency                 | 2
#  Violation code         | 000
#  Violation Description  | 17104h
#  Fine amount            | null
#  Latitude               | 6440041.1
#  Longitude              | 1802686.2
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 4-----------------------------------------
#  Ticket number          | 1105461453
#  Issue Date             | 2015-09-15T00:00:00.000
#  Issue time             | 115
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 200316
#  VIN                    | null
#  Make                   | CHEV
#  Body Style             | PA
#  Color                  | BK
#  Location               | GEORGIA ST/OLYMPIC
#  Route                  | 1FB70
#  Agency                 | 1
#  Violation code         | 8069A
#  Violation Description  | NO STOPPING/STANDING
#  Fine amount            | 93
#  Latitude               | 99999
#  Longitude              | 99999
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 5-----------------------------------------
#  Ticket number          | 1106226590
#  Issue Date             | 2015-09-15T00:00:00.000
#  Issue time             | 19
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201507
#  VIN                    | null
#  Make                   | CHEV
#  Body Style             | VN
#  Color                  | GY
#  Location               | SAN PEDRO S/O BOYD
#  Route                  | 1A35W
#  Agency                 | 1
#  Violation code         | 4000A1
#  Violation Description  | NO EVIDENCE OF REG
#  Fine amount            | 50
#  Latitude               | 99999
#  Longitude              | 99999
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 6-----------------------------------------
#  Ticket number          | 1106500452
#  Issue Date             | 2015-12-17T00:00:00.000
#  Issue time             | 1710
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201605
#  VIN                    | null
#  Make                   | MAZD
#  Body Style             | PA
#  Color                  | BL
#  Location               | SUNSET/ALVARADO
#  Route                  | 00217
#  Agency                 | 1
#  Violation code         | 8070
#  Violation Description  | PARK IN GRID LOCK ZN
#  Fine amount            | 163
#  Latitude               | 99999
#  Longitude              | 99999
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 7-----------------------------------------
#  Ticket number          | 1106500463
#  Issue Date             | 2015-12-17T00:00:00.000
#  Issue time             | 1710
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201602
#  VIN                    | null
#  Make                   | TOYO
#  Body Style             | PA
#  Color                  | BK
#  Location               | SUNSET/ALVARADO
#  Route                  | 00217
#  Agency                 | 1
#  Violation code         | 8070
#  Violation Description  | PARK IN GRID LOCK ZN
#  Fine amount            | 163
#  Latitude               | 99999
#  Longitude              | 99999
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 8-----------------------------------------
#  Ticket number          | 1106506402
#  Issue Date             | 2015-12-22T00:00:00.000
#  Issue time             | 945
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201605
#  VIN                    | null
#  Make                   | CHEV
#  Body Style             | PA
#  Color                  | BR
#  Location               | 721 S WESTLAKE
#  Route                  | 2A75
#  Agency                 | 1
#  Violation code         | 8069AA
#  Violation Description  | NO STOP/STAND AM
#  Fine amount            | 93
#  Latitude               | 99999
#  Longitude              | 99999
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 9-----------------------------------------
#  Ticket number          | 1106506413
#  Issue Date             | 2015-12-22T00:00:00.000
#  Issue time             | 1100
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201701
#  VIN                    | null
#  Make                   | NISS
#  Body Style             | PA
#  Color                  | SI
#  Location               | 1159 HUNTLEY DR
#  Route                  | 2A75
#  Agency                 | 1
#  Violation code         | 8069AA
#  Violation Description  | NO STOP/STAND AM
#  Fine amount            | 93
#  Latitude               | 99999
#  Longitude              | 99999
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 10----------------------------------------
#  Ticket number          | 1106506424
#  Issue Date             | 2015-12-22T00:00:00.000
#  Issue time             | 1100
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201511
#  VIN                    | null
#  Make                   | FORD
#  Body Style             | TR
#  Color                  | WH
#  Location               | 1159 HUNTLEY DR
#  Route                  | 2A75
#  Agency                 | 1
#  Violation code         | 8069AA
#  Violation Description  | NO STOP/STAND AM
#  Fine amount            | 93
#  Latitude               | 99999
#  Longitude              | 99999
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 11----------------------------------------
#  Ticket number          | 1106506435
#  Issue Date             | 2015-12-22T00:00:00.000
#  Issue time             | 1105
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201701
#  VIN                    | null
#  Make                   | CHRY
#  Body Style             | PA
#  Color                  | GO
#  Location               | 1159 HUNTLEY DR
#  Route                  | 2A75
#  Agency                 | 1
#  Violation code         | 8069AA
#  Violation Description  | NO STOP/STAND AM
#  Fine amount            | 93
#  Latitude               | 99999
#  Longitude              | 99999
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 12----------------------------------------
#  Ticket number          | 1106506446
#  Issue Date             | 2015-12-22T00:00:00.000
#  Issue time             | 1110
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201511
#  VIN                    | null
#  Make                   | BMW
#  Body Style             | PA
#  Color                  | BK
#  Location               | 1200 W MIRAMAR
#  Route                  | 2A75
#  Agency                 | 1
#  Violation code         | 4000A1
#  Violation Description  | NO EVIDENCE OF REG
#  Fine amount            | 50
#  Latitude               | 99999
#  Longitude              | 99999
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 13----------------------------------------
#  Ticket number          | 1106549754
#  Issue Date             | 2015-12-15T00:00:00.000
#  Issue time             | 825
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201607
#  VIN                    | null
#  Make                   | PTRB
#  Body Style             | TR
#  Color                  | BK
#  Location               | 4TH/STATE
#  Route                  | CM96
#  Agency                 | 1
#  Violation code         | 8069A
#  Violation Description  | NO STOPPING/STANDING
#  Fine amount            | 93
#  Latitude               | 99999
#  Longitude              | 99999
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 14----------------------------------------
#  Ticket number          | 1107179581
#  Issue Date             | 2015-12-27T00:00:00.000
#  Issue time             | 1055
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201605
#  VIN                    | null
#  Make                   | TOYO
#  Body Style             | PA
#  Color                  | BK
#  Location               | 3100 N HOLLYRIDGE DR
#  Route                  | null
#  Agency                 | 54
#  Violation code         | 8058L
#  Violation Description  | PREF PARKING
#  Fine amount            | 68
#  Latitude               | 99999
#  Longitude              | 99999
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 15----------------------------------------
#  Ticket number          | 1107179592
#  Issue Date             | 2015-12-27T00:00:00.000
#  Issue time             | 1200
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201602
#  VIN                    | null
#  Make                   | MBNZ
#  Body Style             | PA
#  Color                  | BK
#  Location               | 3115 N BERENDO DR
#  Route                  | null
#  Agency                 | 54
#  Violation code         | 8058L
#  Violation Description  | PREF PARKING
#  Fine amount            | 68
#  Latitude               | 99999
#  Longitude              | 99999
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 16----------------------------------------
#  Ticket number          | 1107179603
#  Issue Date             | 2015-12-27T00:00:00.000
#  Issue time             | 1400
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201611
#  VIN                    | null
#  Make                   | NISS
#  Body Style             | PA
#  Color                  | WH
#  Location               | 3100 N BEACHWOOD DR
#  Route                  | null
#  Agency                 | 54
#  Violation code         | 8058L
#  Violation Description  | PREF PARKING
#  Fine amount            | 68
#  Latitude               | 99999
#  Longitude              | 99999
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 17----------------------------------------
#  Ticket number          | 1107539823
#  Issue Date             | 2015-09-16T00:00:00.000
#  Issue time             | 2120
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201502
#  VIN                    | null
#  Make                   | NISS
#  Body Style             | PA
#  Color                  | null
#  Location               | BLAINE/11TH PL
#  Route                  | 1FB95
#  Agency                 | 1
#  Violation code         | 4000A1
#  Violation Description  | NO EVIDENCE OF REG
#  Fine amount            | 50
#  Latitude               | 99999
#  Longitude              | 99999
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 18----------------------------------------
#  Ticket number          | 1107539834
#  Issue Date             | 2015-09-16T00:00:00.000
#  Issue time             | 1045
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | null
#  VIN                    | null
#  Make                   | CHEV
#  Body Style             | PA
#  Color                  | BK
#  Location               | 1246 S FIGUEROA ST
#  Route                  | 1L20
#  Agency                 | 1
#  Violation code         | 8069AP
#  Violation Description  | NO STOP/STAND PM
#  Fine amount            | 93
#  Latitude               | 99999
#  Longitude              | 99999
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 19----------------------------------------
#  Ticket number          | 1107780811
#  Issue Date             | 2015-12-22T00:00:00.000
#  Issue time             | 1102
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201606
#  VIN                    | null
#  Make                   | HOND
#  Body Style             | PA
#  Color                  | BK
#  Location               | PLATA/RAMPART
#  Route                  | 2A1
#  Agency                 | 1
#  Violation code         | 8069B
#  Violation Description  | NO PARKING
#  Fine amount            | 73
#  Latitude               | 99999
#  Longitude              | 99999
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# only showing top 20 rows

# %%
# B.2 - Print the schema for the DataFrame
df.printSchema()
# Out:
# root
#  |-- Ticket number: string (nullable = true)
#  |-- Issue Date: string (nullable = true)
#  |-- Issue time: string (nullable = true)
#  |-- Meter Id: string (nullable = true)
#  |-- Marked Time: string (nullable = true)
#  |-- RP State Plate: string (nullable = true)
#  |-- Plate Expiry Date: string (nullable = true)
#  |-- VIN: string (nullable = true)
#  |-- Make: string (nullable = true)
#  |-- Body Style: string (nullable = true)
#  |-- Color: string (nullable = true)
#  |-- Location: string (nullable = true)
#  |-- Route: string (nullable = true)
#  |-- Agency: string (nullable = true)
#  |-- Violation code: string (nullable = true)
#  |-- Violation Description: string (nullable = true)
#  |-- Fine amount: string (nullable = true)
#  |-- Latitude: string (nullable = true)
#  |-- Longitude: string (nullable = true)
#  |-- Agency Description: string (nullable = true)
#  |-- Color Description: string (nullable = true)
#  |-- Body Style Description: string (nullable = true)

# %%
# B.2 - Count rows in the CSV file
df.count()
# Out:
# 13077724

# %%
# B.4 - Count the number of partitions in the underlying RDD
df_rdd = df.rdd
df_rdd.getNumPartitions()
# Out:
# 16

# %%
# B.5 - Drop the columns VIN, Latitute, Longitute
df2 = df.drop("VIN", "Latitude","Longitude")

df2.printSchema() # Print schema
df2.show(truncate=False, vertical=True) # Show to confirm changes
# Out:
# root
#  |-- Ticket number: string (nullable = true)
#  |-- Issue Date: string (nullable = true)
#  |-- Issue time: string (nullable = true)
#  |-- Meter Id: string (nullable = true)
#  |-- Marked Time: string (nullable = true)
#  |-- RP State Plate: string (nullable = true)
#  |-- Plate Expiry Date: string (nullable = true)
#  |-- Make: string (nullable = true)
#  |-- Body Style: string (nullable = true)
#  |-- Color: string (nullable = true)
#  |-- Location: string (nullable = true)
#  |-- Route: string (nullable = true)
#  |-- Agency: string (nullable = true)
#  |-- Violation code: string (nullable = true)
#  |-- Violation Description: string (nullable = true)
#  |-- Fine amount: string (nullable = true)
#  |-- Agency Description: string (nullable = true)
#  |-- Color Description: string (nullable = true)
#  |-- Body Style Description: string (nullable = true)
#
# -RECORD 0-----------------------------------------
#  Ticket number          | 1103341116
#  Issue Date             | 2015-12-21T00:00:00.000
#  Issue time             | 1251
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 200304
#  Make                   | HOND
#  Body Style             | PA
#  Color                  | GY
#  Location               | 13147 WELBY WAY
#  Route                  | 01521
#  Agency                 | 1
#  Violation code         | 4000A1
#  Violation Description  | NO EVIDENCE OF REG
#  Fine amount            | 50
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 1-----------------------------------------
#  Ticket number          | 1103700150
#  Issue Date             | 2015-12-21T00:00:00.000
#  Issue time             | 1435
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201512
#  Make                   | GMC
#  Body Style             | VN
#  Color                  | WH
#  Location               | 525 S MAIN ST
#  Route                  | 1C51
#  Agency                 | 1
#  Violation code         | 4000A1
#  Violation Description  | NO EVIDENCE OF REG
#  Fine amount            | 50
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 2-----------------------------------------
#  Ticket number          | 1104803000
#  Issue Date             | 2015-12-21T00:00:00.000
#  Issue time             | 2055
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201503
#  Make                   | NISS
#  Body Style             | PA
#  Color                  | BK
#  Location               | 200 WORLD WAY
#  Route                  | 2R2
#  Agency                 | 2
#  Violation code         | 8939
#  Violation Description  | WHITE CURB
#  Fine amount            | 58
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 3-----------------------------------------
#  Ticket number          | 1104820732
#  Issue Date             | 2015-12-26T00:00:00.000
#  Issue time             | 1515
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | null
#  Make                   | ACUR
#  Body Style             | PA
#  Color                  | WH
#  Location               | 100 WORLD WAY
#  Route                  | 2F11
#  Agency                 | 2
#  Violation code         | 000
#  Violation Description  | 17104h
#  Fine amount            | null
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 4-----------------------------------------
#  Ticket number          | 1105461453
#  Issue Date             | 2015-09-15T00:00:00.000
#  Issue time             | 115
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 200316
#  Make                   | CHEV
#  Body Style             | PA
#  Color                  | BK
#  Location               | GEORGIA ST/OLYMPIC
#  Route                  | 1FB70
#  Agency                 | 1
#  Violation code         | 8069A
#  Violation Description  | NO STOPPING/STANDING
#  Fine amount            | 93
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 5-----------------------------------------
#  Ticket number          | 1106226590
#  Issue Date             | 2015-09-15T00:00:00.000
#  Issue time             | 19
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201507
#  Make                   | CHEV
#  Body Style             | VN
#  Color                  | GY
#  Location               | SAN PEDRO S/O BOYD
#  Route                  | 1A35W
#  Agency                 | 1
#  Violation code         | 4000A1
#  Violation Description  | NO EVIDENCE OF REG
#  Fine amount            | 50
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 6-----------------------------------------
#  Ticket number          | 1106500452
#  Issue Date             | 2015-12-17T00:00:00.000
#  Issue time             | 1710
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201605
#  Make                   | MAZD
#  Body Style             | PA
#  Color                  | BL
#  Location               | SUNSET/ALVARADO
#  Route                  | 00217
#  Agency                 | 1
#  Violation code         | 8070
#  Violation Description  | PARK IN GRID LOCK ZN
#  Fine amount            | 163
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 7-----------------------------------------
#  Ticket number          | 1106500463
#  Issue Date             | 2015-12-17T00:00:00.000
#  Issue time             | 1710
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201602
#  Make                   | TOYO
#  Body Style             | PA
#  Color                  | BK
#  Location               | SUNSET/ALVARADO
#  Route                  | 00217
#  Agency                 | 1
#  Violation code         | 8070
#  Violation Description  | PARK IN GRID LOCK ZN
#  Fine amount            | 163
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 8-----------------------------------------
#  Ticket number          | 1106506402
#  Issue Date             | 2015-12-22T00:00:00.000
#  Issue time             | 945
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201605
#  Make                   | CHEV
#  Body Style             | PA
#  Color                  | BR
#  Location               | 721 S WESTLAKE
#  Route                  | 2A75
#  Agency                 | 1
#  Violation code         | 8069AA
#  Violation Description  | NO STOP/STAND AM
#  Fine amount            | 93
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 9-----------------------------------------
#  Ticket number          | 1106506413
#  Issue Date             | 2015-12-22T00:00:00.000
#  Issue time             | 1100
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201701
#  Make                   | NISS
#  Body Style             | PA
#  Color                  | SI
#  Location               | 1159 HUNTLEY DR
#  Route                  | 2A75
#  Agency                 | 1
#  Violation code         | 8069AA
#  Violation Description  | NO STOP/STAND AM
#  Fine amount            | 93
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 10----------------------------------------
#  Ticket number          | 1106506424
#  Issue Date             | 2015-12-22T00:00:00.000
#  Issue time             | 1100
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201511
#  Make                   | FORD
#  Body Style             | TR
#  Color                  | WH
#  Location               | 1159 HUNTLEY DR
#  Route                  | 2A75
#  Agency                 | 1
#  Violation code         | 8069AA
#  Violation Description  | NO STOP/STAND AM
#  Fine amount            | 93
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 11----------------------------------------
#  Ticket number          | 1106506435
#  Issue Date             | 2015-12-22T00:00:00.000
#  Issue time             | 1105
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201701
#  Make                   | CHRY
#  Body Style             | PA
#  Color                  | GO
#  Location               | 1159 HUNTLEY DR
#  Route                  | 2A75
#  Agency                 | 1
#  Violation code         | 8069AA
#  Violation Description  | NO STOP/STAND AM
#  Fine amount            | 93
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 12----------------------------------------
#  Ticket number          | 1106506446
#  Issue Date             | 2015-12-22T00:00:00.000
#  Issue time             | 1110
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201511
#  Make                   | BMW
#  Body Style             | PA
#  Color                  | BK
#  Location               | 1200 W MIRAMAR
#  Route                  | 2A75
#  Agency                 | 1
#  Violation code         | 4000A1
#  Violation Description  | NO EVIDENCE OF REG
#  Fine amount            | 50
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 13----------------------------------------
#  Ticket number          | 1106549754
#  Issue Date             | 2015-12-15T00:00:00.000
#  Issue time             | 825
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201607
#  Make                   | PTRB
#  Body Style             | TR
#  Color                  | BK
#  Location               | 4TH/STATE
#  Route                  | CM96
#  Agency                 | 1
#  Violation code         | 8069A
#  Violation Description  | NO STOPPING/STANDING
#  Fine amount            | 93
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 14----------------------------------------
#  Ticket number          | 1107179581
#  Issue Date             | 2015-12-27T00:00:00.000
#  Issue time             | 1055
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201605
#  Make                   | TOYO
#  Body Style             | PA
#  Color                  | BK
#  Location               | 3100 N HOLLYRIDGE DR
#  Route                  | null
#  Agency                 | 54
#  Violation code         | 8058L
#  Violation Description  | PREF PARKING
#  Fine amount            | 68
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 15----------------------------------------
#  Ticket number          | 1107179592
#  Issue Date             | 2015-12-27T00:00:00.000
#  Issue time             | 1200
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201602
#  Make                   | MBNZ
#  Body Style             | PA
#  Color                  | BK
#  Location               | 3115 N BERENDO DR
#  Route                  | null
#  Agency                 | 54
#  Violation code         | 8058L
#  Violation Description  | PREF PARKING
#  Fine amount            | 68
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 16----------------------------------------
#  Ticket number          | 1107179603
#  Issue Date             | 2015-12-27T00:00:00.000
#  Issue time             | 1400
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201611
#  Make                   | NISS
#  Body Style             | PA
#  Color                  | WH
#  Location               | 3100 N BEACHWOOD DR
#  Route                  | null
#  Agency                 | 54
#  Violation code         | 8058L
#  Violation Description  | PREF PARKING
#  Fine amount            | 68
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 17----------------------------------------
#  Ticket number          | 1107539823
#  Issue Date             | 2015-09-16T00:00:00.000
#  Issue time             | 2120
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201502
#  Make                   | NISS
#  Body Style             | PA
#  Color                  | null
#  Location               | BLAINE/11TH PL
#  Route                  | 1FB95
#  Agency                 | 1
#  Violation code         | 4000A1
#  Violation Description  | NO EVIDENCE OF REG
#  Fine amount            | 50
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 18----------------------------------------
#  Ticket number          | 1107539834
#  Issue Date             | 2015-09-16T00:00:00.000
#  Issue time             | 1045
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | null
#  Make                   | CHEV
#  Body Style             | PA
#  Color                  | BK
#  Location               | 1246 S FIGUEROA ST
#  Route                  | 1L20
#  Agency                 | 1
#  Violation code         | 8069AP
#  Violation Description  | NO STOP/STAND PM
#  Fine amount            | 93
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# -RECORD 19----------------------------------------
#  Ticket number          | 1107780811
#  Issue Date             | 2015-12-22T00:00:00.000
#  Issue time             | 1102
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201606
#  Make                   | HOND
#  Body Style             | PA
#  Color                  | BK
#  Location               | PLATA/RAMPART
#  Route                  | 2A1
#  Agency                 | 1
#  Violation code         | 8069B
#  Violation Description  | NO PARKING
#  Fine amount            | 73
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
# only showing top 20 rows

# %%
# B.6 - Find maximum fine amount. How many fines have this amount?

from pyspark.sql.functions import col
from pyspark.sql.functions import max
from pyspark.sql.functions import count

# Extract fine amount column
fineCol = df2.select(col("Fine amount").cast('float'))

# Find max fine
fineCol.select(max(col("Fine amount"))).show()

# Count max fine entries
fineCol.select('Fine amount').where(col("Fine amount") == 1100.0).count()
# Out:
# +----------------+
# |max(Fine amount)|
# +----------------+
# |          1100.0|
# +----------------+
# 626

# %%
# B.7 - Show the top 20 most frequent vehicle makes, and their frequencies
countMake = df2.groupBy('Make').count().sort(col("count").desc()).show()
# Out:
# [Stage 12:=================================================>      (14 + 2) / 16]
# +----+-------+
# |Make|  count|
# +----+-------+
# |TOYT|2150768|
# |HOND|1479996|
# |FORD|1116235|
# |NISS| 945133|
# |CHEV| 892676|
# | BMW| 603092|
# |MERZ| 543298|
# |VOLK| 432030|
# |HYUN| 404917|
# |DODG| 391686|
# |LEXS| 368420|
# | KIA| 328155|
# |JEEP| 316300|
# |AUDI| 255395|
# |MAZD| 242344|
# |OTHR| 205546|
# | GMC| 184889|
# |INFI| 174315|
# |CHRY| 159948|
# |SUBA| 154640|
# +----+-------+
# only showing top 20 rows

# %%
# B.8 - Create new column 'Color long', mapping the colors to their corresponding values

from pyspark.sql.functions import udf
from pyspark.sql.types import StringType

COLORS = {
'AL':'Aluminum', 'AM':'Amber', 'BG':'Beige', 'BK':'Black', 'BL':'Blue',
'BN':'Brown', 'BR':'Brown', 'BZ':'Bronze', 'CH':'Charcoal', 'DK':'Dark',
'GD':'Gold', 'GO':'Gold', 'GN':'Green', 'GY':'Gray', 'GT':'Granite',
'IV':'Ivory', 'LT':'Light', 'OL':'Olive', 'OR':'Orange', 'MR':'Maroon',
'PK':'Pink', 'RD':'Red', 'RE':'Red', 'SI':'Silver', 'SL':'Silver',
'SM':'Smoke', 'TN':'Tan', 'VT':'Violet', 'WT':'White', 'WH':'White',
'YL':'Yellow', 'YE':'Yellow', 'UN':'Unknown'
}

# Define color mapping function
def mapColor(col):
    try:
        return COLORS[col]
    except:
        return COLORS['UN']

# Make UDF
mapColorUDF = udf(lambda x: mapColor(x),StringType())

# Add column with UDF and display
df3 = df2.withColumn("Color long", mapColorUDF(col("Color"))) 
df3.show(truncate=False, vertical=True)
# Out:
# -RECORD 0-----------------------------------------
#  Ticket number          | 1103341116
#  Issue Date             | 2015-12-21T00:00:00.000
#  Issue time             | 1251
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 200304
#  Make                   | HOND
#  Body Style             | PA
#  Color                  | GY
#  Location               | 13147 WELBY WAY
#  Route                  | 01521
#  Agency                 | 1
#  Violation code         | 4000A1
#  Violation Description  | NO EVIDENCE OF REG
#  Fine amount            | 50
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | Gray
# -RECORD 1-----------------------------------------
#  Ticket number          | 1103700150
#  Issue Date             | 2015-12-21T00:00:00.000
#  Issue time             | 1435
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201512
#  Make                   | GMC
#  Body Style             | VN
#  Color                  | WH
#  Location               | 525 S MAIN ST
#  Route                  | 1C51
#  Agency                 | 1
#  Violation code         | 4000A1
#  Violation Description  | NO EVIDENCE OF REG
#  Fine amount            | 50
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | White
# -RECORD 2-----------------------------------------
#  Ticket number          | 1104803000
#  Issue Date             | 2015-12-21T00:00:00.000
#  Issue time             | 2055
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201503
#  Make                   | NISS
#  Body Style             | PA
#  Color                  | BK
#  Location               | 200 WORLD WAY
#  Route                  | 2R2
#  Agency                 | 2
#  Violation code         | 8939
#  Violation Description  | WHITE CURB
#  Fine amount            | 58
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | Black
# -RECORD 3-----------------------------------------
#  Ticket number          | 1104820732
#  Issue Date             | 2015-12-26T00:00:00.000
#  Issue time             | 1515
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | null
#  Make                   | ACUR
#  Body Style             | PA
#  Color                  | WH
#  Location               | 100 WORLD WAY
#  Route                  | 2F11
#  Agency                 | 2
#  Violation code         | 000
#  Violation Description  | 17104h
#  Fine amount            | null
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | White
# -RECORD 4-----------------------------------------
#  Ticket number          | 1105461453
#  Issue Date             | 2015-09-15T00:00:00.000
#  Issue time             | 115
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 200316
#  Make                   | CHEV
#  Body Style             | PA
#  Color                  | BK
#  Location               | GEORGIA ST/OLYMPIC
#  Route                  | 1FB70
#  Agency                 | 1
#  Violation code         | 8069A
#  Violation Description  | NO STOPPING/STANDING
#  Fine amount            | 93
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | Black
# -RECORD 5-----------------------------------------
#  Ticket number          | 1106226590
#  Issue Date             | 2015-09-15T00:00:00.000
#  Issue time             | 19
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201507
#  Make                   | CHEV
#  Body Style             | VN
#  Color                  | GY
#  Location               | SAN PEDRO S/O BOYD
#  Route                  | 1A35W
#  Agency                 | 1
#  Violation code         | 4000A1
#  Violation Description  | NO EVIDENCE OF REG
#  Fine amount            | 50
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | Gray
# -RECORD 6-----------------------------------------
#  Ticket number          | 1106500452
#  Issue Date             | 2015-12-17T00:00:00.000
#  Issue time             | 1710
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201605
#  Make                   | MAZD
#  Body Style             | PA
#  Color                  | BL
#  Location               | SUNSET/ALVARADO
#  Route                  | 00217
#  Agency                 | 1
#  Violation code         | 8070
#  Violation Description  | PARK IN GRID LOCK ZN
#  Fine amount            | 163
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | Blue
# -RECORD 7-----------------------------------------
#  Ticket number          | 1106500463
#  Issue Date             | 2015-12-17T00:00:00.000
#  Issue time             | 1710
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201602
#  Make                   | TOYO
#  Body Style             | PA
#  Color                  | BK
#  Location               | SUNSET/ALVARADO
#  Route                  | 00217
#  Agency                 | 1
#  Violation code         | 8070
#  Violation Description  | PARK IN GRID LOCK ZN
#  Fine amount            | 163
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | Black
# -RECORD 8-----------------------------------------
#  Ticket number          | 1106506402
#  Issue Date             | 2015-12-22T00:00:00.000
#  Issue time             | 945
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201605
#  Make                   | CHEV
#  Body Style             | PA
#  Color                  | BR
#  Location               | 721 S WESTLAKE
#  Route                  | 2A75
#  Agency                 | 1
#  Violation code         | 8069AA
#  Violation Description  | NO STOP/STAND AM
#  Fine amount            | 93
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | Brown
# -RECORD 9-----------------------------------------
#  Ticket number          | 1106506413
#  Issue Date             | 2015-12-22T00:00:00.000
#  Issue time             | 1100
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201701
#  Make                   | NISS
#  Body Style             | PA
#  Color                  | SI
#  Location               | 1159 HUNTLEY DR
#  Route                  | 2A75
#  Agency                 | 1
#  Violation code         | 8069AA
#  Violation Description  | NO STOP/STAND AM
#  Fine amount            | 93
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | Silver
# -RECORD 10----------------------------------------
#  Ticket number          | 1106506424
#  Issue Date             | 2015-12-22T00:00:00.000
#  Issue time             | 1100
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201511
#  Make                   | FORD
#  Body Style             | TR
#  Color                  | WH
#  Location               | 1159 HUNTLEY DR
#  Route                  | 2A75
#  Agency                 | 1
#  Violation code         | 8069AA
#  Violation Description  | NO STOP/STAND AM
#  Fine amount            | 93
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | White
# -RECORD 11----------------------------------------
#  Ticket number          | 1106506435
#  Issue Date             | 2015-12-22T00:00:00.000
#  Issue time             | 1105
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201701
#  Make                   | CHRY
#  Body Style             | PA
#  Color                  | GO
#  Location               | 1159 HUNTLEY DR
#  Route                  | 2A75
#  Agency                 | 1
#  Violation code         | 8069AA
#  Violation Description  | NO STOP/STAND AM
#  Fine amount            | 93
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | Gold
# -RECORD 12----------------------------------------
#  Ticket number          | 1106506446
#  Issue Date             | 2015-12-22T00:00:00.000
#  Issue time             | 1110
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201511
#  Make                   | BMW
#  Body Style             | PA
#  Color                  | BK
#  Location               | 1200 W MIRAMAR
#  Route                  | 2A75
#  Agency                 | 1
#  Violation code         | 4000A1
#  Violation Description  | NO EVIDENCE OF REG
#  Fine amount            | 50
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | Black
# -RECORD 13----------------------------------------
#  Ticket number          | 1106549754
#  Issue Date             | 2015-12-15T00:00:00.000
#  Issue time             | 825
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201607
#  Make                   | PTRB
#  Body Style             | TR
#  Color                  | BK
#  Location               | 4TH/STATE
#  Route                  | CM96
#  Agency                 | 1
#  Violation code         | 8069A
#  Violation Description  | NO STOPPING/STANDING
#  Fine amount            | 93
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | Black
# -RECORD 14----------------------------------------
#  Ticket number          | 1107179581
#  Issue Date             | 2015-12-27T00:00:00.000
#  Issue time             | 1055
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201605
#  Make                   | TOYO
#  Body Style             | PA
#  Color                  | BK
#  Location               | 3100 N HOLLYRIDGE DR
#  Route                  | null
#  Agency                 | 54
#  Violation code         | 8058L
#  Violation Description  | PREF PARKING
#  Fine amount            | 68
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | Black
# -RECORD 15----------------------------------------
#  Ticket number          | 1107179592
#  Issue Date             | 2015-12-27T00:00:00.000
#  Issue time             | 1200
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201602
#  Make                   | MBNZ
#  Body Style             | PA
#  Color                  | BK
#  Location               | 3115 N BERENDO DR
#  Route                  | null
#  Agency                 | 54
#  Violation code         | 8058L
#  Violation Description  | PREF PARKING
#  Fine amount            | 68
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | Black
# -RECORD 16----------------------------------------
#  Ticket number          | 1107179603
#  Issue Date             | 2015-12-27T00:00:00.000
#  Issue time             | 1400
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201611
#  Make                   | NISS
#  Body Style             | PA
#  Color                  | WH
#  Location               | 3100 N BEACHWOOD DR
#  Route                  | null
#  Agency                 | 54
#  Violation code         | 8058L
#  Violation Description  | PREF PARKING
#  Fine amount            | 68
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | White
# -RECORD 17----------------------------------------
#  Ticket number          | 1107539823
#  Issue Date             | 2015-09-16T00:00:00.000
#  Issue time             | 2120
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201502
#  Make                   | NISS
#  Body Style             | PA
#  Color                  | null
#  Location               | BLAINE/11TH PL
#  Route                  | 1FB95
#  Agency                 | 1
#  Violation code         | 4000A1
#  Violation Description  | NO EVIDENCE OF REG
#  Fine amount            | 50
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | Unknown
# -RECORD 18----------------------------------------
#  Ticket number          | 1107539834
#  Issue Date             | 2015-09-16T00:00:00.000
#  Issue time             | 1045
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | null
#  Make                   | CHEV
#  Body Style             | PA
#  Color                  | BK
#  Location               | 1246 S FIGUEROA ST
#  Route                  | 1L20
#  Agency                 | 1
#  Violation code         | 8069AP
#  Violation Description  | NO STOP/STAND PM
#  Fine amount            | 93
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | Black
# -RECORD 19----------------------------------------
#  Ticket number          | 1107780811
#  Issue Date             | 2015-12-22T00:00:00.000
#  Issue time             | 1102
#  Meter Id               | null
#  Marked Time            | null
#  RP State Plate         | CA
#  Plate Expiry Date      | 201606
#  Make                   | HOND
#  Body Style             | PA
#  Color                  | BK
#  Location               | PLATA/RAMPART
#  Route                  | 2A1
#  Agency                 | 1
#  Violation code         | 8069B
#  Violation Description  | NO PARKING
#  Fine amount            | 73
#  Agency Description     | null
#  Color Description      | null
#  Body Style Description | null
#  Color long             | Black
# only showing top 20 rows

# %%
# B.9 - Find the most frequent color value for Toyotas
df3.groupBy('Color long').count().sort(col("count").desc()).show()
# Out:
# [Stage 16:========================================================(16 + 0) / 16]
# +----------+-------+
# |Color long|  count|
# +----------+-------+
# |     White|2922676|
# |     Black|2846765|
# |      Gray|2567571|
# |    Silver|1682040|
# |      Blue|1007674|
# |       Red| 680418|
# |     Green| 336771|
# |     Brown| 243429|
# |   Unknown| 218526|
# |      Gold| 159727|
# |    Maroon| 148768|
# |       Tan|  93064|
# |     Beige|  79378|
# |    Yellow|  50299|
# |    Orange|  38121|
# |      Pink|   1998|
# |  Charcoal|    326|
# |    Bronze|    152|
# |     Olive|     14|
# |     Smoke|      2|
# +----------+-------+
# only showing top 20 rows

# %% [markdown]
# ## Answer
#
# The most frequent color value for Toyotas is white.
